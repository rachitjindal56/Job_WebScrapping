# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from urllib.request import urlopen
import html.parser
import os
import warnings
warnings.filterwarnings('ignore')

# %%
url = "https://in.indeed.com/jobs?q=&l=Anywhere"

pages = []
pages.append(url)

i = 0
        
job_title = []
company = []
location = []

while len(pages) != 0:
    
    page = pages[0]
    pages.pop()
    
    if i > 20:
        break
    try:
        px = urlopen(page)
    except:
        print("Error")

    soup = BeautifulSoup(px,"html.parser")
    
    for a in soup.findAll('div',attrs = {"class":"job_seen_beacon"}):
        job_title.append(a.findAll('span')[1].text)
        company.append(a.find('span',attrs={"class":"companyName"}).text)
        location.append(a.find('div',attrs={"class":"companyLocation"}).text)
        
    for pg in soup1.findAll('ul',attrs={"class":"pagination-list"}):
        pages.append("https://in.indeed.com"+pg.findAll('a',href=True)[-1]['href'])

    i = i+1

# %%
print(job_title,company,location,sep="\n")
# Out:
# ['Ride.Swiggy', 'Delivery Drivers / Delivery Executives / Delivery Boys / Fre...', 'Supply Clerk- All Interested Applicants', 'CK Birla Hospital, Delhi', 'Looking for a Data Entry operator', 'Hindi call center', 'Customer Success Executive - Remote', 'Flipkart/AMAZON Hiring for Verification Inbound Process', 'VOICE & NON VOICE WORK FOR FRESHERS', 'Operations Support', 'Designer Profile', 'Jio Customer Associate - Freelancer JP', 'Secretary', 'Computer Operator cum Office Assistant', 'Executive / Sr Executive Warehouse', 'Oracle Functional HCM - Associate 2', 'Gold Loan Relationship Officer-LOANS AGAINST GOLD-Marketing...', 'Article Assistant', 'Medical Coder', 'Consultant-BFILL2-CMITS', 'Data Science Intern', 'customer support Executive', 'Business Analysis', 'USI-EH22-EA-NSE BSO C&I-CRC AM', 'Job | RHR-Bangalore-Broking experience must', 'Automotive Powertrain System (Electrification projects) - Sy...', 'Recruitment Executive', 'HIL tester for 48V electrification projects', 'Account
# ...

# %%
job_data = { "Company":company,"Job Title":job_title,"Location":location}

data = pd.DataFrame(data=job_data)
data.to_csv("./job_data.csv")
